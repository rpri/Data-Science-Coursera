# %%
# %pwd
import pandas as pd
import string
import numpy as np
#import numpy as np

indicator = pd.read_excel("/home/ashish/Data_Extract_From_Gender_Statistics_copy.xlsx",index_col=0)#,skipcols=2,skiprows=17,skipfooter=38)
#indicator.drop(['Unnamed: 1'],inplace=True,axis=1)
indicator1=[]
#energy.rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'%Renewable'},inplace=True)
indicator1= indicator[['Series Code','Country Name','1990 [YR1990]','1991 [YR1991]','1992 [YR1992]','1993 [YR1993]','1994 [YR1994]','1995 [YR1995]','1996 [YR1996]','1997 [YR1997]','1998 [YR1998]','1999 [YR1999]','2001 [YR2001]','2002 [YR2002]','2003 [YR2003]','2004 [YR2004]','2005 [YR2005]','2006 [YR2006]','2007 [YR2007]','2008 [YR2008]','2009 [YR2009]','2010 [YR2010]','2011 [YR2011]','2012 [YR2012]','2013 [YR2013]','2014 [YR2014]','2015 [YR2015]']]
#print(indicator1.head)
indicator1=indicator1[indicator1['Series Code']=='SL.TLF.BASC.FE.ZS']
indicator1=indicator1.rename(columns ={'1990 [YR1990]':1990,'1991 [YR1991]':1991,'1992 [YR1992]':1992, '1993 [YR1993]':1993,'1994 [YR1994]':1994,'1995 [YR1995]':1995,'1996 [YR1996]':1996,'1997 [YR1997]':1997, '1998 [YR1998]':1998, '1999 [YR1999]':1999,   '2001 [YR2001]':2001, '2002 [YR2002]':2002, '2003 [YR2003]':2003, '2004 [YR2004]':2004,'2005 [YR2005]':2005, '2006 [YR2006]':2006, '2007 [YR2007]':2007, '2008 [YR2008]':2008,  '2009 [YR2009]':2009, '2010 [YR2010]':2010, '2011 [YR2011]':2011, '2012 [YR2012]':2012,'2013 [YR2013]':2013, '2014 [YR2014]':2014, '2015 [YR2015]':2015})
#'Country','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
print("original",indicator1.head)
country_list = ['Arab World','China','Europe & Central Asia (excluding high income','United States','South Asia (IDA & IBRD)']
#indicator1 = indicator1[indicator1['Country Name'] in country_list]
indicator2=indicator1[indicator1['Country Name'].isin(country_list)]

#df[df.name.isin(value_list)]
#indicator1.replace('\s+',np.NAN,regex=True)
#indicator2[indicator2.Series Code.notnull()]

#print(indicator2.columns)
#print(indicator2.head)
indicator2.drop('Series Code',axis =1,inplace=True)
#print(indicator2.columns)
#print(indicator2_Arab.shape)

indicator2= pd.melt(indicator2, id_vars=['Country Name'], value_vars=[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])

#pd.melt(df, id_vars='country', value_vars=[2010, 2011, 2012])
indicator2=indicator2.rename(columns = {'variable':'Year','value':'Literacy rate'})
indicator2= indicator2[pd.notnull(indicator2['Literacy rate'])]
#indicator2.replace('\s+',np.NAN,regex=True)

indicator2_Arab=indicator2[indicator2['Country Name']=='Arab World']
indicator2_China=indicator2[indicator2['Country Name']=='China']
indicator2_US=indicator2[indicator2['Country Name']=='United States']
indicator2_US=indicator2[indicator2['Country Name']=='South Asia (IDA & IBRD)']
#print(indicator2_Arab.columns) 
#print(indicator2_Arab.head)
#print(indicator2_Arab.head,5)

# %%
# %pwd
# Out:
# '/home/ashish'

# %%
import pandas as pd
stats = pd.read_excel ('/home/ashish/HNP_StatsEXCEL (copy).xlsx',)
#GDP.columns=['Country Code','Indicator Name','Indicator Code','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
#GDP['Country']=GDP.index
#GDP=GDP.reset_index()
print(stats.columns)
stats0=[]
stats0 = stats[['Country Name','Indicator Name','Indicator Code',1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]]
#stats1=stats1
#GDP.columns = ['Country','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
stats0.replace('\s+',np.NAN,regex=True)
stats0 = stats0[stats0['Country Name'].isin(country_list)]

stats1=stats0[stats0['Indicator Code']=='SP.ADO.TFRT' ]
s2=stats0[stats0['Indicator Code']=='SP.POP.1519.FE.5Y']
#print(stats1.head)
#stats1.drop('Indicator Code',axis =1,inplace=True)
#print(indicator2.columns)
#print(indicator2_Arab.shape)
stats2= pd.melt(stats1, id_vars=['Country Name'], value_vars=[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
s2= pd.melt(s2, id_vars=['Country Name'], value_vars=[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])

#print("m",indicator2.columns)
#pd.melt(df, id_vars='country', value_vars=[2010, 2011, 2012])
stats2=stats2.rename(columns = {'variable':'Year','value':'Fertility rate'})
stats2_Arab=stats2[stats2['Country Name']=='Arab World']
stats2_China=stats2[stats2['Country Name']=='China']
stats2_US=stats2[stats2['Country Name']=='United States']
stats2_US=stats2[stats2['Country Name']=='South Asia (IDA & IBRD)']

s2=s2.rename(columns = {'variable':'Year','value':'Literacy rate'})
s2_Arab=s2[s2['Country Name']=='Arab World']
s2_China=s2[s2['Country Name']=='China']
s2_US=s2[s2['Country Name']=='United States']
s2_US=s2[s2['Country Name']=='South Asia (IDA & IBRD)']
print(s2_Arab.columns)            
#print(stats2_Arab.head,5)
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                    1960,           '1961',           '1962',           '1963',
#                  '1964',           '1965',           '1966',           '1967',
#                  '1968',           '1969',           '1970',           '1971',
#                  '1972',           '1973',           '1974',           '1975',
#                  '1976',           '1977',           '1978',           '1979',
#                  '1980',           '1981',           '1982',           '1983',
#                  '1984',           '1985',           '1986',           '1987',
#                  '1988',           '1989',             1990,             1991,
#                    1992,             1993,             1994,             1995,
#                    1996,             1997,             1998,             1999,
#                    2000,             2001,             2002,             2003,
# ...

# %%
m1=pd.merge(stats2_Arab,indicator2_Arab,how='inner',left_on='Country Name',right_on='Country Name')
#m1.sort_values(by='avgGDP', inplace=True, ascending=False)
#m3=m1.set_index('Country Name')
#print(m1.columns)
#print(m1.head)
def merged_data():
      return m1

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt


    
data= merged_data()
 #Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
  #Top15['Citable docs per Capita'] = Top15['Citable documents'] / Top15['PopEst']
#fig=plt.figure()
#stats2_Arab.plot(x='Year', y='Fertility rate', kind='scatter')#, xlim=[0, 0.0006])
#s2_Arab.plot(x='Year', y='Literacy rate', kind='bar')
#plt.plot(data[''], '-o', data['Literacy rate'], '-o')
fig=plt.figure()
host=fig.add_subplot(111)
par=host.twinx()

host.set_ylabel("Fertility rate of female (15-19agegroup)(Births per 1000)")
par.set_ylabel("Literacy rate of female (15-19agegroup)(as % of population)")

line1,=host.plot(stats2_Arab['Year'], stats2_Arab['Fertility rate'],color='Red')#, xlim=[0, 0.0006])
line2,=par.plot(s2_Arab['Year'], s2_Arab['Literacy rate'])
host.legend([line1, line2], ['Fertility Rate', 'Literacy rate'])

plt.title('Literacy and Fertility rates for females(15-19 agegroup)')
plt.xlabel("Time period")
plt.show()
#df_13_14_target[['month','2014_target_val']].plot(x='month',linestyle='-', marker='o')
#df_13_14_target[['month','2013_val','2014_val']].plot(x='month', kind='bar')
# Out:
# <img src="data:image/png;base64,...">
